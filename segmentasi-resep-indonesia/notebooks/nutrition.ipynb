# %%
import pandas as pd

# %% [markdown]
# # Data Cleaning

# %%
df_nutrition = pd.read_csv("nutrition.csv")

# %%
df_nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1346 entries, 0 to 1345
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1346 non-null   int64
#  1   calories      1346 non-null   float64
#  2   proteins      1346 non-null   float64
#  3   fat           1346 non-null   float64
#  4   carbohydrate  1346 non-null   float64
#  5   name          1346 non-null   object
#  6   image         1346 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 73.7+ KB

# %%
len(df_nutrition.drop_duplicates()) / len(df_nutrition)
#jika output dari code di cell ini tidak bernilai 1 maka terdapat duplikat
# Out:
# 1.0

# %% [markdown]
# ## Data Cleaning Review

# %% [markdown]
# 1. Tidak ada missing value ketika dicek dengan fungsi isna
# 2. Tidak ada duplikated data pada dataset ini

# %%
df_nutrition.head()
# Out:
#    id  calories  proteins   fat  carbohydrate                name  \
# 0   1     280.0       9.2  28.4           0.0                Abon
# 1   2     513.0      23.7  37.0          21.3        Abon haruwan
# 2   3       0.0       0.0   0.2           0.0           Agar-agar
# 3   4      45.0       1.1   0.4          10.8  Akar tonjong segar
# 4   5      37.0       4.4   0.5           3.8       Aletoge segar
#
#                                                image
# 0  https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# 1  https://img-global.cpcdn.com/recipes/cbf330fbd...
# 2  https://res.cloudinary.com/dk0z4ums3/image/upl...
# 3  https://images.tokopedia.net/img/cache/200-squ...
# 4  https://nilaigizi.com/assets/images/produk/pro...

# %%
top_protein_foods = df_nutrition.sort_values(by='proteins', ascending=False).head(10)
low_fat_foods = df_nutrition[df_nutrition['fat'] < 10]

# %%
low_fat_foods
# Out:
#         id  calories  proteins  fat  carbohydrate                name  \
# 2        3       0.0       0.0  0.2           0.0           Agar-agar
# 3        4      45.0       1.1  0.4          10.8  Akar tonjong segar
# 4        5      37.0       4.4  0.5           3.8       Aletoge segar
# 5        6      85.0       0.9  6.5           7.7       Alpukat segar
# 6        7      96.0       3.7  0.6          19.1  Ampas kacang hijau
# ...    ...       ...       ...  ...           ...                 ...
# 1341  1342      42.0       1.2  0.6           9.3        Wortel Segar
# 1342  1343      37.0       1.0  0.6           8.3        Wortel kukus
# 1343  1344      28.0       0.7  0.5           6.3        Wortel rebus
# 1344  1345     254.0       3.0  1.1          58.1              Yangko
# 1345  1346      52.0       3.3  2.5           4.0             Yoghurt
#
#                                                   image
# 2     https://res.cloudinary.com/dk0z4ums3/image/upl...
# ...

# %%
df_nutrition_selected = df_nutrition[[
    'id',
    'name',
    'calories',
    'proteins',
    'fat',
    'carbohydrate'
]].astype({
    'id': 'int',
    'name': 'string',
    'calories': 'float',
    'proteins': 'float',
    'fat': 'float',
    'carbohydrate': 'float'
})

# %%
df_nutrition_selected
# Out:
#         id                name  calories  proteins   fat  carbohydrate
# 0        1                Abon     280.0       9.2  28.4           0.0
# 1        2        Abon haruwan     513.0      23.7  37.0          21.3
# 2        3           Agar-agar       0.0       0.0   0.2           0.0
# 3        4  Akar tonjong segar      45.0       1.1   0.4          10.8
# 4        5       Aletoge segar      37.0       4.4   0.5           3.8
# ...    ...                 ...       ...       ...   ...           ...
# 1341  1342        Wortel Segar      42.0       1.2   0.6           9.3
# 1342  1343        Wortel kukus      37.0       1.0   0.6           8.3
# 1343  1344        Wortel rebus      28.0       0.7   0.5           6.3
# 1344  1345              Yangko     254.0       3.0   1.1          58.1
# 1345  1346             Yoghurt      52.0       3.3   2.5           4.0
#
# [1346 rows x 6 columns]

# %%
df_nutrition_selected = df_nutrition_selected.reset_index(drop=True)

# %%
df_nutrition_selected
# Out:
#         id                name  calories  proteins   fat  carbohydrate
# 0        1                Abon     280.0       9.2  28.4           0.0
# 1        2        Abon haruwan     513.0      23.7  37.0          21.3
# 2        3           Agar-agar       0.0       0.0   0.2           0.0
# 3        4  Akar tonjong segar      45.0       1.1   0.4          10.8
# 4        5       Aletoge segar      37.0       4.4   0.5           3.8
# ...    ...                 ...       ...       ...   ...           ...
# 1341  1342        Wortel Segar      42.0       1.2   0.6           9.3
# 1342  1343        Wortel kukus      37.0       1.0   0.6           8.3
# 1343  1344        Wortel rebus      28.0       0.7   0.5           6.3
# 1344  1345              Yangko     254.0       3.0   1.1          58.1
# 1345  1346             Yoghurt      52.0       3.3   2.5           4.0
#
# [1346 rows x 6 columns]

# %%
df_nutrition_selected.to_csv('selected_nutrition.csv', index=False)
