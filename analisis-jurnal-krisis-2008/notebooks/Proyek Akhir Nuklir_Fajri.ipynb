# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns 
from sklearn.model_selection import train_test_split

# %%
# Baca file CSV
df_1 = pd.read_csv("nuclear_energy_overview_eia.csv")

# %%
df_1.head()
# Out:
#    Year     Month Nuclear Generating Units, Total Operable Units  \
# 0  1973   January                                  Not Available
# 1  1973  February                                  Not Available
# 2  1973     March                                  Not Available
# 3  1973     April                                  Not Available
# 4  1973       May                                  Not Available
#
#    Nuclear Generating Units, Net Summer Capacity  \
# 0                                         14.533
# 1                                         14.533
# 2                                         15.314
# 3                                         15.314
# 4                                         16.174
#
#    Nuclear Electricity Net Generation  \
# 0                                6246
# 1                                5928
# 2                                6649
# 3                                5876
# 4                                5697
#
# ...

# %%
df_2 = pd.read_csv("number_of_plants_producing_uranium_in_us.csv")
df_2.head()
# Out:
#    Year  Mills - conventional milling  Mills - other operations  \
# 0  2000                             1                         2
# 1  2001                             0                         1
# 2  2002                             0                         1
# 3  2003                             0                         0
# 4  2004                             0                         0
#
#    In-situ recovery plants  Byproduct recovery plants
# 0                        3                          0
# 1                        3                          0
# 2                        2                          0
# 3                        2                          0
# 4                        3                          0

# %%
df_3 = pd.read_csv("power_plant_database_global.csv")
df_3.head()
df_3.columns
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22476\2375117370.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_3 = pd.read_csv("power_plant_database_global.csv")
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh_2013', 'estimated_generation_gwh_2014',
#        'estimated_generation_gwh_2015', 'estimated_generation_gwh_2016',
#        'estimated_generation_gwh_2017', 'estimated_generation_note_2013',
# ...

# %%
df_4 = pd.read_csv("rates_death_from_energy_production_per_twh.csv")
df_4.head()
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Entity                                    9 non-null      object
#  1   Deaths per TWh of electricity production  9 non-null      float64
#  2   Year                                      9 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 348.0+ bytes

# %%
df_5 = pd.read_csv("reactors_parent_companies.csv")
df_5.head()
# Out:
#                          Plant Name, Unit Number  \
# 0                                 Callaway Plant
# 1  Palo Verde Nuclear Generating Station, Unit 1
# 2  Palo Verde Nuclear Generating Station, Unit 2
# 3  Palo Verde Nuclear Generating Station, Unit 3
# 4                Millstone Power Station, Unit 2
#
#       Parent Company Utility Name Parent Company Website  Year of Update
# 0                        AmerenUE         www.ameren.com            2020
# 1  Arizona Public Service Company            www.aps.com            2020
# 2  Arizona Public Service Company            www.aps.com            2020
# 3  Arizona Public Service Company            www.aps.com            2020
# 4             Dominion Generation            www.dom.com            2020

# %%
df_6 = pd.read_csv("uranium_production_summary_us.csv")
df_6.head()
# Out:
#    Year Exploration and development surface drililng  \
# 0  2009                                          3.7
# 1  2010                                          4.9
# 2  2011                                          6.3
# 3  2012                                          7.2
# 4  2013                                          3.8
#
#   Exploration and development drilling  expenditures  \
# 0                                               35.4
# 1                                               44.6
# 2                                               53.6
# 3                                               66.6
# 4                                               49.9
#
#   Mine production of uranium Uranium concentrate production  \
# 0                        4.1                            3.7
# 1                        4.2                            4.2
# 2                        4.1                            4.0
# 3                        4.3                            4.1
# ...

# %%
df_7 = pd.read_csv("uranium_purchase_price_us.csv")
df_7.head()
# Out:
#    Delivery year  Total purchased Purchased from U.S. producers  \
# 0           2002            10.36                         13.03
# 1           2003            10.81                         14.17
# 2           2004            12.61                           - -
# 3           2005            14.36                             W
# 4           2006            18.61                           - -
#
#   Purchased from U.S. brokers and traders  \
# 0                                   10.21
# 1                                   11.05
# 2                                   12.08
# 3                                   13.76
# 4                                   20.49
#
#   Purchased from other owners and operators of U.S. civilian nuclear power reactors, other U.S. suppliers, (and U.S. government for 2007)  \
# 0                                                  W
# 1                                              10.16
# 2                                              11.30
# ...

# %%
df_8 = pd.read_csv("us_nuclear_generating_statistics_1971_2021.csv")
df_8.head()
# Out:
#    YEAR  TOTAL ELECTRICITY GENERATION  NUCLEAR GENERATION  NUCLEAR FUEL SHARE  \
# 0  1971                    1615853616            38104545                 2.4
# 1  1972                    1752978413            54091135                 3.1
# 2  1973                    1864056631            83479463                 4.5
# 3  1974                    1870319405           113975740                 6.1
# 4  1975                    1920754569           172505075                 9.0
#
#    CAPACITY FACTOR  SUMMER CAPACITY
# 0             48.2             9033
# 1             42.5            14481
# 2             53.5            22683
# 3             47.8            31867
# 4             55.9            37267

# %%
df_9 = pd.read_csv("world_electricity_generation.csv")
df_9.head()
# Out:
#    Year  Month  nuclear_generation_twh  share_of_generation_pct
# 0  2019      1                  242.40                    11.10
# 1  2019      2                  219.65                    10.96
# 2  2019      3                  232.28                    11.04
# 3  2019      4                  215.00                    10.87
# 4  2019      5                  218.44                    10.46

# %%
df_10 = pd.read_csv("world_nuclear_energy_generation.csv")
df_10.head()
# Out:
#         Entity  Year  electricity_from_nuclear_twh  share_of_electricity_pct
# 0  Afghanistan  2000                           0.0                       0.0
# 1  Afghanistan  2001                           0.0                       0.0
# 2  Afghanistan  2002                           0.0                       0.0
# 3  Afghanistan  2003                           0.0                       0.0
# 4  Afghanistan  2004                           0.0                       0.0
